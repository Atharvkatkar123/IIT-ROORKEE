# %%
# !pip install opencv-python
# Out:
# ...
#    ---------------------------------------- 0.0/39.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/39.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/39.5 MB ? eta -:--:--
#     --------------------------------------- 0.8/39.5 MB 2.1 MB/s eta 0:00:19
#     --------------------------------------- 0.8/39.5 MB 2.1 MB/s eta 0:00:19
#    - -------------------------------------- 1.0/39.5 MB 1.2 MB/s eta 0:00:33
#    - -------------------------------------- 1.3/39.5 MB 1.2 MB/s eta 0:00:33
#    - -------------------------------------- 1.3/39.5 MB 1.2 MB/s eta 0:00:33
#    - -------------------------------------- 1.3/39.5 MB 1.2 MB/s eta 0:00:33
#    - -------------------------------------- 1.6/39.5 MB 932.2 kB/s eta 0:00:41
#    - -------------------------------------- 1.8/39.5 MB 915.5 kB/s eta 0:00:42
#    - -------------------------------------- 1.8/39.5 MB 915.5 kB/s eta 0:00:42
# ...

# %%
import cv2

# %%
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
cap = cv2.VideoCapture(0)
while True:
    ret, frame = cap.read()

    face_cascade = cv2.CascadeClassifier(r'C:\Users\katka\Downloads\haarcascade_frontalface_default.xml')
    smile_cascade = cv2.CascadeClassifier(r'C:\Users\katka\Downloads\haarcascade_smile.xml')

    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    faces = face_cascade.detectMultiScale(gray,minNeighbors=5)

    for (x,y,w,h) in faces:
        cv2.rectangle(frame, (x,y), (x+w,y+h),(255, 255, 255),2)

        roi_gray = gray[y:y+h,x:x+w]
        roi_color = frame[y:y+h,x:x+w]

        smiles = smile_cascade.detectMultiScale(roi_gray,scaleFactor=2,minNeighbors=25,minSize=(27,27))


        for (sx,sy,sw,sh) in smiles:
            cv2.rectangle(roi_color,(sx, sy), (sx+sw, sy+sh), (255, 255, 255),2)
            cv2.putText(frame, "Hey You Just Smiled..!",(x,y-10), cv2.FONT_HERSHEY_TRIPLEX,0.5,(255, 255, 255),1)

    cv2.imshow('Webcam Frame', frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
